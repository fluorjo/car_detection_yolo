# %% [markdown]
# https://iagreebut.tistory.com/70

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
cp -r aialone_car/test ./aialone_car_grey/test

# %%
# %pip install scikit-image
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from skimage import color
from skimage import io
import matplotlib.pyplot as plt
import cv2
import os

# %%
# %cd /content/drive/MyDrive/aialone_car_grey
# Out:
# /content/drive/MyDrive/aialone_car_grey

# %%
# imagepath='/content/drive/MyDrive/aialone_car_grey/test2.png'
imagepath='syn_00000.png'

# %%
image = cv2.imread(imagepath)
grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayscale, cmap="gray"); # Grayscale Image

# %%
dst1 =cv2.equalizeHist(grayscale)

# %%
plt.imshow(dst1, cmap="gray"); # Grayscale Image

# %%
dst2 = cv2.normalize(grayscale, None, 0, 255, cv2.NORM_MINMAX)

# %%
plt.imshow(dst2, cmap="gray"); # Grayscale Image

# %%
cv2.imwrite(imagepath,grayscale)
# Out:
# True

# %%
image = cv2.imread(imagepath)
plt.imshow(image) # Original Image

# %%
def rgb2gray(imagepath):
  image = cv2.imread(imagepath)
  grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  cv2.imwrite(imagepath,grayscale)

# %%
imagepath='/content/drive/MyDrive/aialone_car_grey/test3.png'

# %%
root='/content/drive/MyDrive/aialone_car_grey/'

# %%
print(os.listdir(root+'/test'))
# Out:
# ['142405547.png', '142409878.png', '142412275.png', '142426156.png', '142437849.png', '142440575.png', '142533520.png', '142535542.png', '142536179.png', '142537456.png', '142549024.png', '142554121.png', '142609912.png', '142625451.png', '142629176.png', '142634878.png', '142635167.png', '142635650.png', '142640891.png', '142711681.png', '142718351.png', '142719850.png', '142720689.png', '142728890.png', '142729156.png', '142729457.png', '142736669.png', '142739147.png', '142746318.png', '142801952.png', '142824714.png', '142827681.png', '142828416.png', '142829992.png', '142835814.png', '142858659.png', '142900983.png', '142910882.png', '142934253.png', '142943178.png', '142943851.png', '142944852.png', '142953181.png', '143004144.png', '143009348.png', '143014502.png', '143018331.png', '143023351.png', '143024351.png', '143025557.png', '143029657.png', '143038660.png', '143054289.png', '143058845.png', '143111685.png', '143113383.png', '143139451.png', '143142317.png', '143208985.
# ...

# %%
train_file_list=os.listdir(root+'/train/images')

# %%
val_file_list=os.listdir(root+'/val')

# %%
train_folder_path=root+'train/images/'

# %%
val_folder_path=root+'val/'

# %%
print(train_folder_path)
# Out:
# /content/drive/MyDrive/aialone_car_grey/train/images/

# %%
print(train_folder_path+train_file_list[0])
# Out:
# /content/drive/MyDrive/aialone_car_grey/train/images/syn_01654.png

# %%
image = cv2.imread(train_folder_path+train_file_list[0])
plt.imshow(image) # Original Image

# %%
from tqdm import tqdm

for i in tqdm(train_file_list):
  rgb2gray(train_folder_path+i)
# Out:
# 100%|██████████| 5180/5180 [1:08:56<00:00,  1.25it/s]

# %%
for i in val_file_list:
  rgb2gray(val_folder_path+i)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-70-435287a696c2> in <cell line: 1>()
#       1 for i in val_file_list:
# ----> 2   rgb2gray(val_folder_path+i)
#
# <ipython-input-45-dd2b4ce7b129> in rgb2gray(imagepath)
#       1 def rgb2gray(imagepath):
#       2   image = cv2.imread(imagepath)
# ----> 3   grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       4   cv2.imwrite(imagepath,grayscale)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
