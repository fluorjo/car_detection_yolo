# %%
# %pip install scikit-image

# %%
from skimage import color
from skimage import io

# %%
img = io.imread('1304.png')
imgGray = color.rgb2gray(img)

# %%
import matplotlib.pyplot as plt
plt.imshow(imgGray, cmap = 'gray')

# %%
plt.imshow(img)
